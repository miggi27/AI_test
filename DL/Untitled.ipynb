# %%
import google.protobuf
print(google.protobuf.__version__)
# Out:
# 4.25.3

# %%
import tensorflow as tf
from tensorflow import keras

print(f"TensorFlow 버전: {tf.__version__}")
print(f"Keras 버전: {keras.__version__}")

# 랜덤 시드 설정
keras.utils.set_random_seed(42)
tf.random.set_seed(42)
tf.config.experimental.enable_op_determinism()
print("✅ 설정 완료!")
# Out:
# TensorFlow 버전: 2.15.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       2 from tensorflow import keras
#       4 print(f"TensorFlow 버전: {tf.__version__}")
# ----> 5 print(f"Keras 버전: {keras.__version__}")
#       7 # 랜덤 시드 설정
#       8 keras.utils.set_random_seed(42)
#
# AttributeError: module 'keras.api._v2.keras' has no attribute '__version__'
