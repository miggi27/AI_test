# %%
import cv2
import mediapipe as mp
import math
import numpy as np

def load_img(path):
    img = cv2.imread(path)
    if img is None:
        return np.zeros((300, 300, 3), dtype='uint8')
    return cv2.resize(img, (300, 300))

def get_dist(p1,p2):
    return math.sqrt((p1.x - p2.x)**2 + (p1.y - p2.y)**2)

mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawin
