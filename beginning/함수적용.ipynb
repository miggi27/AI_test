# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col='번호')
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %% [markdown]
# - 주소 컬럼에 '시' 추가 ( 광주 => 광주시 )

# %%
df['주소'] = df['주소']+'시'

# %%
df
# Out:
#      이름   주소  나이   점수      언어
# 번호
# 1번  김길동  광주시  33   76  Python
# 2번  이길동  서울시  23   88    Java
# 3번  강길동  대구시  30   98     C++
# 4번  홍길동  대전시  20  100     NaN
# 5번  박길동  광주시  21   60     NaN
# 6번  나길동  서울시  25   90       C

# %% [markdown]
# - 점수 컬럼에 '점' 추가

# %%
df['점수'] = df['점수'] + '점'
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df['점수'] = df['점수'] + '점'
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)    184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# ...

# %%
5 + 10
# Out:
# 15

# %%
5 + 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 5 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
def add_jum(jum):
    return str(jum) + '점'

df['점수'] = df['점수'].apply(add_jum)
df
# Out:
#      이름   주소  나이    점수      언어
# 번호
# 1번  김길동  광주시  33   76점  Python
# 2번  이길동  서울시  23   88점    Java
# 3번  강길동  대구시  30   98점     C++
# 4번  홍길동  대전시  20  100점     NaN
# 5번  박길동  광주시  21   60점     NaN
# 6번  나길동  서울시  25   90점       C

# %%
df = pd.read_excel('score.xlsx', index_col='번호')

# %%
df['점수'] = df['점수'].apply(lambda x: str(x) + '점')
df
# Out:
#      이름  주소  나이    점수      언어
# 번호
# 1번  김길동  광주  33   76점  Python
# 2번  이길동  서울  23   88점    Java
# 3번  강길동  대구  30   98점     C++
# 4번  홍길동  대전  20  100점     NaN
# 5번  박길동  광주  21   60점     NaN
# 6번  나길동  서울  25   90점       C

# %%
df['언어'] = df['언어'].str.upper()
df
# Out:
#      이름  주소  나이    점수      언어
# 번호
# 1번  김길동  광주  33   76점  PYTHON
# 2번  이길동  서울  23   88점    JAVA
# 3번  강길동  대구  30   98점     C++
# 4번  홍길동  대전  20  100점     NaN
# 5번  박길동  광주  21   60점     NaN
# 6번  나길동  서울  25   90점       C

# %%
def cap(lang):
    if pd.notnull(lang):
        return lang.capitalize()
df['언어'] = df['언어'].apply(cap)
df
# Out:
#      이름  주소  나이    점수      언어
# 번호
# 1번  김길동  광주  33   76점  Python
# 2번  이길동  서울  23   88점    Java
# 3번  강길동  대구  30   98점     C++
# 4번  홍길동  대전  20  100점    None
# 5번  박길동  광주  21   60점    None
# 6번  나길동  서울  25   90점       C

# %%
df = pd.read_excel('score.xlsx', index_col='번호')

# %%
df['언어'] = df['언어'].str.capitalize()

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C
