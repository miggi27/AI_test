# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col='번호')
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %% [markdown]
# ### Column 선택

# %% [markdown]
# #### 이름 / 주소 / 이름,주소,점수

# %%
df['이름']
# Out:
# 번호
# 1번    김길동
# 2번    이길동
# 3번    강길동
# 4번    홍길동
# 5번    박길동
# 6번    나길동
# Name: 이름, dtype: object

# %%
df['주소']
# Out:
# 번호
# 1번    광주
# 2번    서울
# 3번    대구
# 4번    대전
# 5번    광주
# 6번    서울
# Name: 주소, dtype: object

# %%
df[['이름','주소','점수']]
# Out:
#      이름  주소   점수
# 번호
# 1번  김길동  광주   76
# 2번  이길동  서울   88
# 3번  강길동  대구   98
# 4번  홍길동  대전  100
# 5번  박길동  광주   60
# 6번  나길동  서울   90

# %% [markdown]
# #### 컬럼 전체 출력 / 특정 컬럼 선택 / 특정 컬럼으로 데이터 출력

# %%
df.columns
# Out:
# Index(['이름', '주소', '나이', '점수', '언어'], dtype='object')

# %%
df.columns[0]
# Out:
# '이름'

# %%
df.columns[1]
# Out:
# '주소'

# %%
df[df.columns[2]]
# Out:
# 번호
# 1번    33
# 2번    23
# 3번    30
# 4번    20
# 5번    21
# 6번    25
# Name: 나이, dtype: int64

# %%
df[df.columns[-1]]
# Out:
# 번호
# 1번    Python
# 2번      Java
# 3번       C++
# 4번       NaN
# 5번       NaN
# 6번         C
# Name: 언어, dtype: object

# %% [markdown]
# ### 슬라이싱

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %% [markdown]
# #### 점수 컬럼의 특정 인덱스까지 출력

# %%
df['점수'][:4]
# Out:
# 번호
# 1번     76
# 2번     88
# 3번     98
# 4번    100
# Name: 점수, dtype: int64

# %%
df['점수'][:3]
# Out:
# 번호
# 1번    76
# 2번    88
# 3번    98
# Name: 점수, dtype: int64

# %%
df['점수'][2:]
# Out:
# 번호
# 3번     98
# 4번    100
# 5번     60
# 6번     90
# Name: 점수, dtype: int64

# %% [markdown]
# #### 이름과 점수 컬럼의 특정 인덱스까지 출력

# %%
df[['이름','점수']][3:]
# Out:
#      이름   점수
# 번호
# 4번  홍길동  100
# 5번  박길동   60
# 6번  나길동   90

# %%
df[3:]
# Out:
#      이름  주소  나이   점수   언어
# 번호
# 4번  홍길동  대전  20  100  NaN
# 5번  박길동  광주  21   60  NaN
# 6번  나길동  서울  25   90    C

# %% [markdown]
# ### 데이터선택(loc)

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %% [markdown]
# #### 3번 인덱스 행 출력 / 5번 인덱스 행 출력

# %%
df.loc['3번']
# Out:
# 이름    강길동
# 주소     대구
# 나이     30
# 점수     98
# 언어    C++
# Name: 3번, dtype: object

# %%
df.loc['5번']
# Out:
# 이름    박길동
# 주소     광주
# 나이     21
# 점수     60
# 언어    NaN
# Name: 5번, dtype: object

# %% [markdown]
# #### 1번 인덱스의 점수 컬럼값 출력

# %%
df.loc['1번','점수']
# Out:
# np.int64(76)

# %% [markdown]
# #### 1번과 3번 인덱스의 나이 컬럼 값 출력

# %%
df.loc[['1번','3번'], '나이']
# Out:
# 번호
# 1번    33
# 3번    30
# Name: 나이, dtype: int64

# %% [markdown]
# #### 1번과 3번 인덱스의 이름과 나이 컬럼값 출력

# %%
df.loc[['1번','3번'], ['이름','나이']]
# Out:
#      이름  나이
# 번호
# 1번  김길동  33
# 3번  강길동  30

# %% [markdown]
# #### 1번부터 4번 인덱스까지의 이름부터 나이까지 컬럼값 출력

# %%
df.loc['1번':'4번', '이름':'나이'] # 대가로로 묶으면 안되는 상황
# Out:
#      이름  주소  나이
# 번호
# 1번  김길동  광주  33
# 2번  이길동  서울  23
# 3번  강길동  대구  30
# 4번  홍길동  대전  20

# %% [markdown]
# ### 데이터선택(iloc)

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %%
df.loc['1번'] # 문자를 이용
# Out:
# 이름       김길동
# 주소        광주
# 나이        33
# 점수        76
# 언어    Python
# Name: 1번, dtype: object

# %%
df.iloc[0] # 숫자를 이용
# Out:
# 이름       김길동
# 주소        광주
# 나이        33
# 점수        76
# 언어    Python
# Name: 1번, dtype: object

# %%
df.iloc[1,2]
# Out:
# np.int64(23)

# %%
df.iloc[[1,3], 3:]
# Out:
#      점수    언어
# 번호
# 2번   88  Java
# 4번  100   NaN

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %%
df.iloc[1:4, 2:5]
# Out:
#     나이   점수    언어
# 번호
# 2번  23   88  Java
# 3번  30   98   C++
# 4번  20  100   NaN
