# %%
import pandas as pd

# %% [markdown]
# #### score.xlsx 파일 읽기

# %%
df = pd.read_excel('score.xlsx', index_col='번호')
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %% [markdown]
# ### DataFrame 확인

# %% [markdown]
# #### 기초 통계량 확인

# %%
df.describe()
# Out:
#               나이          점수
# count   6.000000    6.000000
# mean   25.333333   85.333333
# std     5.163978   15.055453
# min    20.000000   60.000000
# 25%    21.500000   79.000000
# 50%    24.000000   89.000000
# 75%    28.750000   96.000000
# max    33.000000  100.000000

# %% [markdown]
# #### DataFrame 기본정보 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 1번 to 6번
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      6 non-null      object
#  1   주소      6 non-null      object
#  2   나이      6 non-null      int64
#  3   점수      6 non-null      int64
#  4   언어      4 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 288.0+ bytes

# %% [markdown]
# #### df의 처음 5개 행 확인

# %%
df.head()
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN

# %% [markdown]
# #### df의 처음 3개 행 확인

# %%
df.head(3)
# Out:
#      이름  주소  나이  점수      언어
# 번호
# 1번  김길동  광주  33  76  Python
# 2번  이길동  서울  23  88    Java
# 3번  강길동  대구  30  98     C++

# %% [markdown]
# #### df의 마지막 5개 행 확인

# %%
df.tail()
# Out:
#      이름  주소  나이   점수    언어
# 번호
# 2번  이길동  서울  23   88  Java
# 3번  강길동  대구  30   98   C++
# 4번  홍길동  대전  20  100   NaN
# 5번  박길동  광주  21   60   NaN
# 6번  나길동  서울  25   90     C

# %% [markdown]
# #### df의 마지막 3개 행 확인

# %%
df.tail(3)
# Out:
#      이름  주소  나이   점수   언어
# 번호
# 4번  홍길동  대전  20  100  NaN
# 5번  박길동  광주  21   60  NaN
# 6번  나길동  서울  25   90    C

# %% [markdown]
# #### df의 데이터값 확인

# %%
df.values
# Out:
# array([['김길동', '광주', 33, 76, 'Python'],
#        ['이길동', '서울', 23, 88, 'Java'],
#        ['강길동', '대구', 30, 98, 'C++'],
#        ['홍길동', '대전', 20, 100, nan],
#        ['박길동', '광주', 21, 60, nan],
#        ['나길동', '서울', 25, 90, 'C']], dtype=object)

# %% [markdown]
# #### 인덱스, 컬럼, 구조 확인

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번'], dtype='object', name='번호')

# %%
df.columns
# Out:
# Index(['이름', '주소', '나이', '점수', '언어'], dtype='object')

# %%
df.shape
# Out:
# (6, 5)

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %% [markdown]
# ### Series 확인

# %% [markdown]
# #### Series의 통계량 확인

# %%
df['점수'].describe()
# Out:
# count      6.000000
# mean      85.333333
# std       15.055453
# min       60.000000
# 25%       79.000000
# 50%       89.000000
# 75%       96.000000
# max      100.000000
# Name: 점수, dtype: float64

# %% [markdown]
# #### 점수 컬럼의 최대/최소 / 큰값 순으로 몇개 / 평균 / 합

# %%
df['점수'].min()
# Out:
# 60

# %%
df['점수'].max()
# Out:
# 100

# %%
df['점수'].nlargest(3)
# Out:
# 번호
# 4번    100
# 3번     98
# 6번     90
# Name: 점수, dtype: int64

# %%
df['점수'].mean()
# Out:
# np.float64(85.33333333333333)

# %%
df['점수'].sum()
# Out:
# np.int64(512)

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %% [markdown]
# #### 특정열의 개수 카운트 / 유일값 / 유일값 개수 (언어, 주소 컬럼)

# %%
df['언어'].count()
# Out:
# np.int64(4)

# %%
df['주소'].unique()
# Out:
# array(['광주', '서울', '대구', '대전'], dtype=object)

# %%
df['주소'].nunique()
# Out:
# 4
