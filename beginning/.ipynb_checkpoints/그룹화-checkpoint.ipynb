# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col='번호')
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대구  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %%
df.replace({'주소':{'대구':'대전'}}, inplace=True)
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대전  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %%
df['주소'] = df['주소'].replace({'대구':'대전'})
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대전  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %%
df.groupby('주소')

# %%
df.groupby('주소').get_group('광주')
# Out:
#      이름  주소  나이  점수      언어
# 번호
# 1번  김길동  광주  33  76  Python
# 5번  박길동  광주  21  60     NaN

# %%
df.groupby('주소').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 1번 to 6번
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      6 non-null      object
#  1   주소      6 non-null      object
#  2   나이      6 non-null      int64
#  3   점수      6 non-null      int64
#  4   언어      4 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 288.0+ bytes

# %%
df.groupby('주소').mean(numeric_only=True)
# Out:
#       나이    점수
# 주소
# 광주  27.0  68.0
# 대전  25.0  99.0
# 서울  24.0  89.0

# %%
df.groupby('주소').size()
# Out:
# 주소
# 광주    2
# 대전    2
# 서울    2
# dtype: int64

# %%
df.groupby('주소').size()['광주']
# Out:
# np.int64(2)

# %%
df.groupby('주소')['나이'].mean()
# Out:
# 주소
# 광주    27.0
# 대전    25.0
# 서울    24.0
# Name: 나이, dtype: float64

# %%
df.groupby('주소')[['나이', '점수']].mean()
# Out:
#       나이    점수
# 주소
# 광주  27.0  68.0
# 대전  25.0  99.0
# 서울  24.0  89.0

# %%
df
# Out:
#      이름  주소  나이   점수      언어
# 번호
# 1번  김길동  광주  33   76  Python
# 2번  이길동  서울  23   88    Java
# 3번  강길동  대전  30   98     C++
# 4번  홍길동  대전  20  100     NaN
# 5번  박길동  광주  21   60     NaN
# 6번  나길동  서울  25   90       C

# %%
df.groupby('주소').mean(numeric_only=True).sort_values('점수', ascending=False)
# Out:
#       나이    점수
# 주소
# 대전  25.0  99.0
# 서울  24.0  89.0
# 광주  27.0  68.0
