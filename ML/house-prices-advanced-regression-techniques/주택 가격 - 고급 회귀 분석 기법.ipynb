# %%
데이터 필드
데이터 설명 파일에 포함된 내용을 간략하게 설명드리겠습니다.

SalePrice - 부동산의 매매 가격(달러). 이것이 바로 예측하려는 목표 변수입니다.
MSSubClass : 빌딩 클래스
MSZoning : 일반적인 용도지역 분류
부지 전면 길이 : 부지와 연결된 도로의 선형 길이(피트)
LotArea : 대지 면적(제곱피트)
거리 : 도로 접근 유형
골목길 : 골목길 접근 방식
부지 형태 : 부동산의 전반적인 모양
지형 윤곽 : 부지의 평탄도
공공 서비스 : 이용 가능한 공공 서비스 종류
LotConfig : 로트 구성
토지 경사 : 토지의 경사도
인근 지역 : 에임스 시 경계 내의 물리적 위치
조건 1 : 주요 도로 또는 철도와의 근접성
조건2 : 주요 도로 또는 철도와의 근접성 (두 번째 조건이 있는 경우)
BldgType : 주택 유형
주택 스타일 : 주거 형태
전반적인 품질 : 전반적인 소재 및 마감 품질
전체 상태 : 전체 상태 등급
건축 연도 : 최초 건축 날짜
YearRemodAdd : 리모델링 날짜
지붕 스타일 : 지붕 유형
RoofMatl : 지붕재
Exterior1st : 집의 외부 덮개
Exterior2nd : 주택 외벽 마감재 (재료가 두 가지 이상인 경우)
MasVnrType : 석조 베니어 유형
MasVnrArea : 벽돌 베니어 면적(제곱피트)
ExterQual : 외장재 품질
ExterCond : 자재의 외부에 나타난 현재 상태
기초 : 기초의 종류
BsmtQual : 지하실 높이
BsmtCond : 지하실의 전반적인 상태
지하실 노출 : 워크아웃 또는 정원 레벨 지하실 벽
BsmtFinType1 : 지하실 마감 면적의 품질
BsmtFinSF1 : 1형 완공 면적(제곱피트)
BsmtFinType2 : 두 번째 완공 구역의 품질(있는 경우)
BsmtFinSF2 : 2형 완공 면적(제곱피트)
BsmtUnfSF : 미완성 지하실 면적(제곱피트)
TotalBsmtSF : 지하실의 총 면적(제곱피트)
난방 : 난방 방식
HeatingQC : 난방 품질 및 상태
CentralAir : 중앙 냉방 시스템
전기 : 전기 시스템
1stFlrSF : 1층 면적(제곱피트)
2ndFlrSF : 2층 면적(제곱피트)
LowQualFinSF : 마감 품질이 낮은 면적(모든 층)
GrLivArea : 지상(지면) 생활 공간 면적(제곱피트)
BsmtFullBath : 지하실에 완비된 욕실
BsmtHalfBath : 지하실 간이 화장실
FullBath : 지상층에 완비된 욕실
하프 배스 : 지상에 있는 하프 배스
침실 수 : 지하층을 제외한 위층의 침실 개수
주방 : 주방 개수
KitchenQual : 주방 품질
TotRmsAbvGrd : 지상층 총 객실 수 (욕실 제외)
기능성 : 가정용 기능성 평가
벽난로 : 벽난로 개수
FireplaceQu : 벽난로 품질
차고 유형 : 차고 위치
GarageYrBlt : 차고가 지어진 연도
GarageFinish : 차고 내부 마감
차고 차량 수 : 차고의 크기(수용 차량 대수)
차고 면적 : 차고의 크기(제곱피트)
GarageQual : 차고 품질
GarageCond : 차고 상태
PavedDrive : 포장된 진입로
WoodDeckSF : 목재 데크 면적(제곱피트)
OpenPorchSF : 개방형 현관 면적(제곱피트)
밀폐형 현관 : 밀폐형 현관 면적(제곱피트)
3SsnPorch : 3계절용 베란다 면적(제곱피트)
스크린 포치 : 스크린 포치 면적(제곱피트)
수영장 면적 : 수영장 면적(제곱피트)
PoolQC : 수영장 품질
울타리 : 울타리 품질
기타 기능 : 다른 범주에 포함되지 않은 기타 기능
MiscVal : 기타 기능의 값
월간 판매량 :
YrSold : 판매 연도
판매 유형 : 판매 유형
판매 조건 : 판매 조건

# %%
Data fields
Here's a brief version of what you'll find in the data description file.

SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
MSSubClass: The building class
MSZoning: The general zoning classification
LotFrontage: Linear feet of street connected to property
LotArea: Lot size in square feet
Street: Type of road access
Alley: Type of alley access
LotShape: General shape of property
LandContour: Flatness of the property
Utilities: Type of utilities available
LotConfig: Lot configuration
LandSlope: Slope of property
Neighborhood: Physical locations within Ames city limits
Condition1: Proximity to main road or railroad
Condition2: Proximity to main road or railroad (if a second is present)
BldgType: Type of dwelling
HouseStyle: Style of dwelling
OverallQual: Overall material and finish quality
OverallCond: Overall condition rating
YearBuilt: Original construction date
YearRemodAdd: Remodel date
RoofStyle: Type of roof
RoofMatl: Roof material
Exterior1st: Exterior covering on house
Exterior2nd: Exterior covering on house (if more than one material)
MasVnrType: Masonry veneer type
MasVnrArea: Masonry veneer area in square feet
ExterQual: Exterior material quality
ExterCond: Present condition of the material on the exterior
Foundation: Type of foundation
BsmtQual: Height of the basement
BsmtCond: General condition of the basement
BsmtExposure: Walkout or garden level basement walls
BsmtFinType1: Quality of basement finished area
BsmtFinSF1: Type 1 finished square feet
BsmtFinType2: Quality of second finished area (if present)
BsmtFinSF2: Type 2 finished square feet
BsmtUnfSF: Unfinished square feet of basement area
TotalBsmtSF: Total square feet of basement area
Heating: Type of heating
HeatingQC: Heating quality and condition
CentralAir: Central air conditioning
Electrical: Electrical system
1stFlrSF: First Floor square feet
2ndFlrSF: Second floor square feet
LowQualFinSF: Low quality finished square feet (all floors)
GrLivArea: Above grade (ground) living area square feet
BsmtFullBath: Basement full bathrooms
BsmtHalfBath: Basement half bathrooms
FullBath: Full bathrooms above grade
HalfBath: Half baths above grade
Bedroom: Number of bedrooms above basement level
Kitchen: Number of kitchens
KitchenQual: Kitchen quality
TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
Functional: Home functionality rating
Fireplaces: Number of fireplaces
FireplaceQu: Fireplace quality
GarageType: Garage location
GarageYrBlt: Year garage was built
GarageFinish: Interior finish of the garage
GarageCars: Size of garage in car capacity
GarageArea: Size of garage in square feet
GarageQual: Garage quality
GarageCond: Garage condition
PavedDrive: Paved driveway
WoodDeckSF: Wood deck area in square feet
OpenPorchSF: Open porch area in square feet
EnclosedPorch: Enclosed porch area in square feet
3SsnPorch: Three season porch area in square feet
ScreenPorch: Screen porch area in square feet
PoolArea: Pool area in square feet
PoolQC: Pool quality
Fence: Fence quality
MiscFeature: Miscellaneous feature not covered in other categories
MiscVal: $Value of miscellaneous feature
MoSold: Month Sold
YrSold: Year Sold
SaleType: Type of sale
SaleCondition: Condition of sale

# %%
# 81개 전체 컬럼 한글 의미 사전
col_desc = {
    "MSSubClass": "빌딩 등급 (층수, 시기 등)",
    "MSZoning": "토지 구획 (주거, 상업 등)",
    "LotFrontage": "도로와 맞닿은 길이 (피트)",
    "LotArea": "대지 면적 (제곱피트)",
    "Street": "도로 접근 방식 (자갈, 포장)",
    "Alley": "골목길 접근 방식",
    "LotShape": "부지 모양 (정기적, 불규칙적)",
    "LandContour": "지형의 평탄도",
    "Utilities": "이용 가능한 공공시설 (전기, 가스 등)",
    "LotConfig": "부지 구성 (코너, 막다른 길 등)",
    "LandSlope": "부지 경사도",
    "Neighborhood": "에임스 시 내의 구역명",
    "Condition1": "주변 도로/철도 인접 조건 1",
    "Condition2": "주변 도로/철도 인접 조건 2 (둘 이상일 때)",
    "BldgType": "주거 형태 (단독주택, 타운하우스 등)",
    "HouseStyle": "주거 스타일 (1층, 2층 등)",
    "OverallQual": "전반적인 재료 및 마감 품질 (1-10)",
    "OverallCond": "전반적인 상태 등급 (1-10)",
    "YearBuilt": "완공 연도",
    "YearRemodAdd": "리모델링 연도",
    "RoofStyle": "지붕 스타일",
    "RoofMatl": "지붕 재료",
    "Exterior1st": "외벽 재료 1",
    "Exterior2nd": "외벽 재료 2",
    "MasVnrType": "석재 외장(Masonry veneer) 유형",
    "MasVnrArea": "석재 외장 면적",
    "ExterQual": "외재 품질",
    "ExterCond": "외재 현재 상태",
    "Foundation": "기초 공사 토대 유형",
    "BsmtQual": "지하실 높이 (품질)",
    "BsmtCond": "지하실 일반 상태",
    "BsmtExposure": "지하실 노출 정도 (정원 등과 연결)",
    "BsmtFinType1": "지하실 마감 상태 1",
    "BsmtFinSF1": "지하실 마감 면적 1",
    "BsmtFinType2": "지하실 마감 상태 2",
    "BsmtFinSF2": "지하실 마감 면적 2",
    "BsmtUnfSF": "지하실 미완성 면적",
    "TotalBsmtSF": "지하실 총 면적",
    "Heating": "난방 방식",
    "HeatingQC": "난방 품질 및 상태",
    "CentralAir": "중앙 냉방 여부 (Y/N)",
    "Electrical": "전기 시스템",
    "1stFlrSF": "1층 면적",
    "2ndFlrSF": "2층 면적",
    "LowQualFinSF": "저품질 마감 면적 (모든 층)",
    "GrLivArea": "지상층 거주 면적 (총 넓이)",
    "BsmtFullBath": "지하실 전체 욕실 수",
    "BsmtHalfBath": "지하실 간이 욕실 수",
    "FullBath": "지상층 전체 욕실 수",
    "HalfBath": "지상층 간이 욕실 수",
    "BedroomAbvGr": "지상층 침실 수",
    "KitchenAbvGr": "지상층 주방 수",
    "KitchenQual": "주방 품질",
    "TotRmsAbvGrd": "지상층 총 방 수 (욕실 제외)",
    "Functional": "주택 기능성 등급",
    "Fireplaces": "벽난로 개수",
    "FireplaceQu": "벽난로 품질",
    "GarageType": "차고 위치",
    "GarageYrBlt": "차고 완공 연도",
    "GarageFinish": "차고 내부 마감",
    "GarageCars": "차고 수용 차량 대수",
    "GarageArea": "차고 면적",
    "GarageQual": "차고 품질",
    "GarageCond": "차고 상태",
    "PavedDrive": "포장 진입로 상태",
    "WoodDeckSF": "나무 데크 면적",
    "OpenPorchSF": "오픈 포치 면적",
    "EnclosedPorch": "폐쇄형 포치 면적",
    "3SsnPorch": "3계절 포치 면적",
    "ScreenPorch": "스크린 포치 면적",
    "PoolArea": "수영장 면적",
    "PoolQC": "수영장 품질",
    "Fence": "울타리 품질",
    "MiscFeature": "기타 특징 (엘리베이터 등)",
    "MiscVal": "기타 특징의 가치($)",
    "MoSold": "판매 월",
    "YrSold": "판매 연도",
    "SaleType": "판매 유형",
    "SaleCondition": "판매 조건",
    "SalePrice": "판매 가격 (Target)"
}

# 확인하고 싶을 때 쓰는 법 (예: Alley가 뭐였지?)
print(f"Alley: {col_desc['Alley']}")
# Out:
# Alley: 골목길 접근 방식

# %% [markdown]
# 🏗️ 1단계: 데이터 탐색 및 이해 (EDA)
#
# 가장 먼저 데이터와 친해지는 단계입니다.
#
# 컬럼 의미 파악: 제공된 data_description.txt를 읽고 각 변수가 수치형인지 범주형(카테고리)인지 구분합니다.
#
# 타겟 변수 확인: 집값(SalePrice)의 분포를 확인합니다. 보통 오른쪽으로 꼬리가 긴 형태라 **로그 변환($log(1+x)$)**을 고려해야 합니다.
#
# 상관관계 분석: 어떤 변수가 집값과 가장 관련이 깊은지 히트맵(Heatmap)으로 확인합니다.
#
# 🧼 2단계: 데이터 전처리 (가장 중요한 구간!)
#
# 데이터가 지저분하면 아무리 좋은 모델도 소용없습니다.
#
# 결측치(Missing Value) 처리: * PoolQC, MiscFeature 등 결측치가 너무 많은 컬럼은 삭제하거나 'None'이라는 새로운 범주로 채웁니다.
#
# 이상치(Outlier) 제거: GrLivArea(지상 거주 면적) 대비 가격이 터무니없이 낮은 데이터 등을 산점도로 찾아 제거합니다.
#
# 인코딩: 범주형 데이터(예: 동네 이름, 지붕 스타일)를 모델이 이해할 수 있게 One-Hot Encoding이나 Label Encoding으로 변환합니다.
#
# 스케일링: 수치 데이터들의 단위를 맞춰줍니다 (StandardScaler 등).
#
# 🤖 3단계: 회귀 모델 구축 (추천 리스트)
#
# 다양한 모델을 써보라고 하셨으니, 아래 3가지 부류를 섞어서 시도해 보세요.
#
# 분류추천 모델특징선형 모델Ridge, Lasso과적합을 방지하는 규제가 포함된 선형 회귀앙상블(트리)Random Forest여러 개의 나무를 심어 평균을 내는 안정적인 모델부스팅(강력 추천)XGBoost, LightGBM현재 정형 데이터 예측에서 가장 성능이 좋은 모델들
#
# 📊 4단계: 성능 평가 (Metrics)
#
# 제시하신 4가지 지표를 산출합니다.
#
# MAE / MSE / RMSE: 기본적인 오차 지표입니다.
#
# RMSLE (Root Mean Squared Logarithmic Error): 이 대회에서 특히 중요하게 보는 지표입니다. 가격의 '비율' 차이를 보기 때문에, 비싼 집과 저렴한 집의 오차를 공정하게 평가합니다.
#
# Tip: SalePrice에 로그를 취해 학습했다면, 예측값에 다시 지수 함수($exp$)를 취해 복구한 뒤 계산해야 합니다.
#
# 🏁 5단계: 모델 비교 및 튜닝
#
# 각 모델별 지표를 **표(Table)**로 정리하여 어떤 모델이 가장 우수한지 비교합니다.
#
# 가장 성능이 좋은 모델의 하이퍼파라미터(Hyperparameter)를 수정하며 성능을 끌어올립니다.
#
# 💡 요약하자면 이 순서로 진행하세요:
#
# 데이터 로드 및 결측치 확인
#
# 수치형/범주형 데이터 전처리
#
# Linear, Ridge, Random Forest, XGBoost 모델 학습
#
# 4가지 지표(MAE, MSE, RMSE, RMSLE) 비교 결과 도출

# %% [markdown]
# ## 🏠 Ames Housing 데이터셋 핵심 컬럼 요약
#
# | 분류 | 주요 컬럼명 | 한글 의미 | 주요 내용 |
# | :--- | :--- | :--- | :--- |
# | **타겟** | **SalePrice** | **판매 가격** | 우리가 예측해야 할 정답 (Target) |
# | **품질/연도** | OverallQual, YearBuilt | 전반적 품질, 완공연도 | 집값과 상관관계가 가장 높은 핵심 변수 |
# | **면적** | GrLivArea, 1stFlrSF, TotalBsmtSF | 거주 면적, 1층/지하실 면적 | 집의 크기를 나타내는 수치형 데이터 |
# | **지하실** | BsmtQual, BsmtCond, BsmtExposure | 지하실 품질, 상태, 노출도 | NaN = '지하실 없음' |
# | **차고** | GarageCars, GarageArea, GarageType | 차고 수용량, 면적, 위치 | NaN = '차고 없음' |
# | **부대시설** | PoolQC, Fence, MiscFeature | 수영장, 울타리, 기타 특징 | 결측치가 많으나 '시설 없음'의 정보임 |
# | **입지** | MSZoning, Neighborhood | 토지 용도, 동네 이름 | 주변 환경 및 지역적 특성 정보 |

# %% [markdown]
# # 🚀 하우스 가격 예측 프로젝트 로드맵
#
# ### 1단계: 데이터 훑어보기 (Data Exploration)
# - [ ] `df.head()`로 상위 데이터 확인
# - [ ] `df.info()`로 숫자형 vs 문자형 변수 구분
# - [ ] `df.describe()`로 평균, 최솟값, 최댓값 파악
#
# ### 2단계: 결측치(Null) 정복하기
# - [ ] `msno.matrix()`로 비어있는 곳 시각화
# - [ ] '원래 없는 것(None)'과 '누락된 것' 구분하기
# - [ ] 범주형은 최빈값이나 'None', 수치형은 0이나 중앙값으로 채우기
#
# ### 3단계: 집값의 핵심 범인 찾기 (Correlation)
# - [ ] `SalePrice`와 상관계수가 높은 Top 10 컬럼 뽑기
# - [ ] 산점도(Scatter Plot)를 그려서 집값과 비례하는지 확인
#
# ### 4단계: 이상치(Outlier) 제거
# - [ ] 땅은 엄청 넓은데 집값이 너무 싼 데이터 등 '이상한 놈' 골라내기

# %% [markdown]
# 영문 컬럼명,의미 (한글),결측치의 진짜 의미,처리 팁
# PoolQC,수영장 품질,수영장 없음,'None'으로 채우기
# MiscFeature,기타 특징 (엘리베이터 등),특별한 시설 없음,'None'으로 채우기
# Alley,골목길 접근성,골목길 연결 안 됨,'None'으로 채우기
# Fence,울타리 상태,울타리 없음,'None'으로 채우기
# FireplaceQu,벽난로 품질,벽난로 없음,'None'으로 채우기
# Garage...,차고 관련 (5개 컬럼),차고 없음,'None' 또는 0으로 채우기
# Bsmt...,지하실 관련 (5개 컬럼),지하실 없음,'None' 또는 0으로 채우기

# %%
# 주피터 노트북 상단에 실행해두면 좋은 코드
import pandas as pd

# 전체 설명을 데이터프레임으로 변환
desc_df = pd.DataFrame.from_dict(col_desc, orient='index', columns=['한글설명'])

# 이제 언제든 아래 명령어로 궁금한 컬럼을 검색할 수 있습니다.
# 예: 'Garage'가 포함된 모든 컬럼 설명 보기
desc_df[desc_df.index.str.contains('Garage')]
# Out:
#                      한글설명
# GarageType          차고 위치
# GarageYrBlt      차고 완공 연도
# GarageFinish     차고 내부 마감
# GarageCars    차고 수용 차량 대수
# GarageArea          차고 면적
# GarageQual          차고 품질
# GarageCond          차고 상태

# %%
import pandas as pd

# %%
# 데이터 불러오기
data = pd.read_csv('train.csv', index_col='Id')
# 81개 전체 컬럼 한글 의미 사전
col_desc = {
    "MSSubClass": "빌딩 등급 (층수, 시기 등)",
    "MSZoning": "토지 구획 (주거, 상업 등)",
    "LotFrontage": "도로와 맞닿은 길이 (피트)",
    "LotArea": "대지 면적 (제곱피트)",
    "Street": "도로 접근 방식 (자갈, 포장)",
    "Alley": "골목길 접근 방식",
    "LotShape": "부지 모양 (정기적, 불규칙적)",
    "LandContour": "지형의 평탄도",
    "Utilities": "이용 가능한 공공시설 (전기, 가스 등)",
    "LotConfig": "부지 구성 (코너, 막다른 길 등)",
    "LandSlope": "부지 경사도",
    "Neighborhood": "에임스 시 내의 구역명",
    "Condition1": "주변 도로/철도 인접 조건 1",
    "Condition2": "주변 도로/철도 인접 조건 2 (둘 이상일 때)",
    "BldgType": "주거 형태 (단독주택, 타운하우스 등)",
    "HouseStyle": "주거 스타일 (1층, 2층 등)",
    "OverallQual": "전반적인 재료 및 마감 품질 (1-10)",
    "OverallCond": "전반적인 상태 등급 (1-10)",
    "YearBuilt": "완공 연도",
    "YearRemodAdd": "리모델링 연도",
    "RoofStyle": "지붕 스타일",
    "RoofMatl": "지붕 재료",
    "Exterior1st": "외벽 재료 1",
    "Exterior2nd": "외벽 재료 2",
    "MasVnrType": "석재 외장(Masonry veneer) 유형",
    "MasVnrArea": "석재 외장 면적",
    "ExterQual": "외재 품질",
    "ExterCond": "외재 현재 상태",
    "Foundation": "기초 공사 토대 유형",
    "BsmtQual": "지하실 높이 (품질)",
    "BsmtCond": "지하실 일반 상태",
    "BsmtExposure": "지하실 노출 정도 (정원 등과 연결)",
    "BsmtFinType1": "지하실 마감 상태 1",
    "BsmtFinSF1": "지하실 마감 면적 1",
    "BsmtFinType2": "지하실 마감 상태 2",
    "BsmtFinSF2": "지하실 마감 면적 2",
    "BsmtUnfSF": "지하실 미완성 면적",
    "TotalBsmtSF": "지하실 총 면적",
    "Heating": "난방 방식",
    "HeatingQC": "난방 품질 및 상태",
    "CentralAir": "중앙 냉방 여부 (Y/N)",
    "Electrical": "전기 시스템",
    "1stFlrSF": "1층 면적",
    "2ndFlrSF": "2층 면적",
    "LowQualFinSF": "저품질 마감 면적 (모든 층)",
    "GrLivArea": "지상층 거주 면적 (총 넓이)",
    "BsmtFullBath": "지하실 전체 욕실 수",
    "BsmtHalfBath": "지하실 간이 욕실 수",
    "FullBath": "지상층 전체 욕실 수",
    "HalfBath": "지상층 간이 욕실 수",
    "BedroomAbvGr": "지상층 침실 수",
    "KitchenAbvGr": "지상층 주방 수",
    "KitchenQual": "주방 품질",
    "TotRmsAbvGrd": "지상층 총 방 수 (욕실 제외)",
    "Functional": "주택 기능성 등급",
    "Fireplaces": "벽난로 개수",
    "FireplaceQu": "벽난로 품질",
    "GarageType": "차고 위치",
    "GarageYrBlt": "차고 완공 연도",
    "GarageFinish": "차고 내부 마감",
    "GarageCars": "차고 수용 차량 대수",
    "GarageArea": "차고 면적",
    "GarageQual": "차고 품질",
    "GarageCond": "차고 상태",
    "PavedDrive": "포장 진입로 상태",
    "WoodDeckSF": "나무 데크 면적",
    "OpenPorchSF": "오픈 포치 면적",
    "EnclosedPorch": "폐쇄형 포치 면적",
    "3SsnPorch": "3계절 포치 면적",
    "ScreenPorch": "스크린 포치 면적",
    "PoolArea": "수영장 면적",
    "PoolQC": "수영장 품질",
    "Fence": "울타리 품질",
    "MiscFeature": "기타 특징 (엘리베이터 등)",
    "MiscVal": "기타 특징의 가치($)",
    "MoSold": "판매 월",
    "YrSold": "판매 연도",
    "SaleType": "판매 유형",
    "SaleCondition": "판매 조건",
    "SalePrice": "판매 가격 (Target)"
}

# %% [markdown]
# ### 1단계: 데이터 훑어보기 (Data Exploration)
# - df.head()로 상위 데이터 확인
# - df.info()로 숫자형 vs 문자형 변수 구분
# - df.describe()로 평균, 최솟값, 최댓값 파악

# %%
data.head(3)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
#
# [3 rows x 80 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %% [markdown]
# ### 2단계: 결측치(Null) 정복하기
# - msno.matrix()로 비어있는 곳 시각화
# - '원래 없는 것(None)'과 '누락된 것' 구분하기
# - 범주형은 최빈값이나 'None', 수치형은 0이나 중앙값으로 채우기

# %%
# 결측치 계산
null_info = data.isnull().sum()
null_info = null_info[null_info > 0].sort_values(ascending=False)

# 데이터프레임으로 만들어서 한글 설명 붙이기
null_df = pd.DataFrame(null_info, columns=['Missing_Count'])
null_df['Description'] = null_df.index.map(col_desc)

print("--- 결측치가 있는 컬럼 상세 정보 ---")
display(null_df)
# Out:
# --- 결측치가 있는 컬럼 상세 정보 ---
# Empty DataFrame
# Columns: [Missing_Count, Description]
# Index: []

# %%
# !pip install missingno

# %%
import missingno as msno
import matplotlib.pyplot as plt

# 전체적인 결측치 위치 확인
msno.matrix(data)
plt.show()
# 컬럼별 데이터 충전도(%) 확인
msno.bar(data)
plt.show()
# 결측치 사이의 상관계수
msno.heatmap(data)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /opt/anaconda3/lib/python3.13/site-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %% [markdown]
# 영문 컬럼명,의미 (한글),결측치의 진짜 의미,처리 팁
# PoolQC,수영장 품질,수영장 없음,'None'으로 채우기
# MiscFeature,기타 특징 (엘리베이터 등),특별한 시설 없음,'None'으로 채우기
# Alley,골목길 접근성,골목길 연결 안 됨,'None'으로 채우기
# Fence,울타리 상태,울타리 없음,'None'으로 채우기
# FireplaceQu,벽난로 품질,벽난로 없음,'None'으로 채우기
# Garage...,차고 관련 (5개 컬럼),차고 없음,'None' 또는 0으로 채우기
# Bsmt...,지하실 관련 (5개 컬럼),지하실 없음,'None' 또는 0으로 채우기

# %% [markdown]
# #### None으로 처리해야 할것들
# - 'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
# - 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond',
# - 'BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtCond', 'BsmtQual'
# #### 그외 수치형, 범주형, 특수케이스 결측치 처리

# %%
# 1. 데이터 로드
train = pd.read_csv('train.csv', index_col='Id')
test = pd.read_csv('test.csv', index_col='Id')

# 2. 나중에 다시 분리하기 위해 train의 행 개수를 저장해둡니다.
ntrain = train.shape[0] # 예: 1460
ntest = test.shape[0]   # 예: 1459

# 3. 타겟 변수(SalePrice)는 따로 보관하고 train에서 삭제합니다. (test에는 원래 없으니까요)
y_train = np.log1p(train['SalePrice'])
train.drop(['SalePrice'], axis=1, inplace=True)

# 4. [핵심] 두 데이터를 하나로 합칩니다. (위-아래로 붙이기)
# 이렇게 하면 전체 데이터에 대해 동일한 전처리(결측치, 인코딩)가 한 번에 적용됩니다.
all_data = pd.concat((train, test))
# all_data.drop(['Id'], axis=1, inplace=True) # 인덱스로 지정해서 삭제하면 안됨

print(f"합쳐진 데이터 크기: {all_data.shape}")

# ---------------------------------------------------------
# 5. [전처리 구간] 여기서 아까 했던 모든 작업을 수행합니다.
# ---------------------------------------------------------

data = all_data.copy()

# 1. [수치형 데이터] - 동네별 중앙값으로 채우기 (LotFrontage)
# 도로 길이는 동네 특성을 따라가므로 Neighborhood 그룹별 중앙값을 사용합니다.
data["LotFrontage"] = data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median())
)

# 2. [수치형 데이터] - 0으로 채우기 (면적, 개수 관련)
# 수영장 면적이나 차고 면적이 결측치면 시설이 없다는 뜻이므로 0을 넣습니다.
for col in ('MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 
            'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 
            'GarageCars', 'GarageArea', 'GarageYrBlt'):
    data[col] = data[col].fillna(0)

# 3. [범주형 데이터] - 최빈값(가장 흔한 값)으로 채우기
# 데이터가 1~2개만 누락된 경우, 가장 많이 나타나는 값으로 채워줍니다.
for col in ('MSZoning', 'Electrical', 'KitchenQual', 'Exterior1st', 
            'Exterior2nd', 'SaleType', 'Functional'):
    data[col] = data[col].fillna(data[col].mode()[0])

# 4. [특수 케이스] - 'None'으로 채우기 (앞서 요청하신 리스트 + 추가)
# 시설이 존재하지 않음을 명시적으로 표시합니다.
none_cols = [
    'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 
    'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 
    'BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'MasVnrType'
]
data[none_cols] = data[none_cols].fillna('None')

# 인코딩 하기 직전에! 남은 결측치를 가장 흔한 값으로 덮어쓰기
for col in data.select_dtypes(include='object').columns:
    data[col] = data[col].fillna(data[col].mode()[0])

# 5. 최종 확인
print("남은 결측치 수:", data.isnull().sum().sum())


from sklearn.preprocessing import LabelEncoder
# 문자열인 컬럼들만 골라서 숫자로 변환
cols = data.select_dtypes(include='object').columns
for c in cols:
    lbl = LabelEncoder() 
    data[c] = lbl.fit_transform(list(data[c].values))

# ---------------------------------------------------------
# 6. [분리 구간] 이제 다시 train과 test로 나눕니다.
# ---------------------------------------------------------
# 처음에 저장해둔 ntrain(행 개수)을 기준으로 자르면 정확합니다.
X_train = data[:ntrain].copy()     # 0부터 ntrain까지가 원래 train
X_test_real = data[ntrain:].copy()  # ntrain부터 끝까지가 원래 test

print(f"복구된 Train 크기: {X_train.shape}") # (1460, 컬럼수)
print(f"복구된 Test 크기: {X_test_real.shape}")  # (1459, 컬럼수)

data = pd.concat([X_train, y_train], axis=1)
# Out:
# 합쳐진 데이터 크기: (2919, 79)
# 남은 결측치 수: 0
# 복구된 Train 크기: (1460, 79)
# 복구된 Test 크기: (1459, 79)

# %%
data
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1             60         3         65.0     8450       1      1         3
# 2             20         3         80.0     9600       1      1         3
# 3             60         3         68.0    11250       1      1         0
# 4             70         3         60.0     9550       1      1         0
# 5             60         3         84.0    14260       1      1         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1456          60         3         62.0     7917       1      1         3
# 1457          20         3         85.0    13175       1      1         3
# 1458          70         3         66.0     9042       1      1         3
# 1459          20         3         68.0     9717       1      1         3
# 1460          20         3         75.0     9937       1      1         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
X_test_real.shape
# Out:
# (1459, 79)

# %%
X_test_real
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1461          20         2         80.0    11622       1      1         3
# 1462          20         3         81.0    14267       1      1         0
# 1463          60         3         74.0    13830       1      1         0
# 1464          60         3         78.0     9978       1      1         0
# 1465         120         3         43.0     5005       1      1         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 2915         160         4         21.0     1936       1      1         3
# 2916         160         4         21.0     1894       1      1         3
# 2917          20         3        160.0    20000       1      1         3
# 2918          85         3         62.0    10441       1      1         3
# 2919          60         3         74.0     9627       1      1         3
#
# ...

# %%
test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# ...

# %% [markdown]
# ### 3단계: 집값의 핵심 범인 찾기 (Correlation)
# - SalePrice와 상관계수가 높은 Top 10 컬럼 뽑기
# - 산점도(Scatter Plot)를 그려서 집값과 비례하는지 확인

# %%
# 1. 모든 컬럼 간의 '친밀도(상관계수)'를 계산합니다.
# 1에 가까울수록 "너 오르면 나도 올라!" 하는 아주 친한 사이입니다.
corrmat = data.corr()

# 2. 'SalePrice'와 친한 정도만 쏙 뽑아냅니다.
# abs()는 마이너스 친밀도(가격 깎아먹는 범인)도 중요하니까 절대값을 씌운 거예요.
# 그중 친밀도가 0.5 이상인 '영향력 있는' 컬럼들의 이름(index)만 가져옵니다.
top_corr_features = corrmat.index[abs(corrmat["SalePrice"]) > 0.5]

# 3. 그 핵심 컬럼들끼리만 다시 관계를 그려봅니다. (히트맵)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
# annot=True는 칸 안에 숫자를 써달라는 뜻이고, cmap은 색상 테마입니다.
sns.heatmap(data[top_corr_features].corr(), annot=True, cmap="RdYlGn")
# Out:
# <Axes: >

# %% [markdown]
# ### 4단계: 이상치(Outlier) 제거
# - 땅은 엄청 넓은데 집값이 너무 싼 데이터 등 '이상한 놈' 골라내기

# %%
# 산점도 그리기
plt.scatter(x=data['GrLivArea'], y=data['SalePrice'])
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# 면적은 4000 넘는데 가격은 300,000 미만인 하단 우측 데이터 삭제 (전형적인 이상치)
data = data.drop(data[(data['GrLivArea']>4000) & (data['SalePrice']<300000)].index)

# %% [markdown]
# #### 5단계: 다양한 회귀 모델 학습 및 성능 평가
# - 이 코드는 Ridge, Lasso, Random Forest, Gradient Boosting 4가지 모델을 동시에 돌리고 성적표를 만들어줍니다.

# %%
# 1. 원래 train 데이터의 개수를 알고 있어야 합니다. (보통 1460개)
# ntrain = 1460 # 만약 이 변수가 지워졌다면 직접 숫자를 넣으세요.

# 2. 전체 데이터 'data'에서 SalePrice가 있는지 확인하고 분리
# 만약 'data' 안에 SalePrice가 포함되어 있다면 아래처럼 처리합니다.
if 'SalePrice' in data.columns:
    # 정답지는 따로 보관 (로그 변환)
    y_all = data['SalePrice'] 
    # 학습용 데이터에서는 정답지 삭제
    X_all = data.drop(['SalePrice'], axis=1)
else:
    # 이미 분리되어 있다면 그대로 사용
    X_all = data

# 3. Train / Test(실제 시험지)로 먼저 크게 나눕니다.
X_train_full = X_all[:ntrain]      # 모델 학습용 전체 특징
y_train_full = y_all[:ntrain]      # 모델 학습용 전체 정답
# X_test_real = X_all[ntrain:]       # 나중에 제출할 진짜 시험지

# 4. [중요] 모델 성능 검증을 위해 Train_full을 다시 Train과 Test로 나눕니다. (8:2 비율)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_train_full, y_train_full, test_size=0.2, random_state=42
)

print(f"학습용(X_train): {X_train.shape}")
print(f"검증용(X_test): {X_test.shape}")
# Out:
# 학습용(X_train): (1164, 79)
# 검증용(X_test): (292, 79)

# %%
X_train
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 255           20         3         70.0     8400       1      1         3
# 1066          60         3         80.0    14000       1      1         3
# 638          190         4         50.0     6000       1      1         3
# 1293          70         4         60.0     6600       1      1         3
# 515           45         3         55.0    10594       1      1         3
# ...          ...       ...          ...      ...     ...    ...       ...
# 1098         120         3         60.0     3696       1      1         3
# 1133          70         4         90.0     9900       1      1         3
# 1298         180         4         35.0     3675       1      1         3
# 863           20         3         81.0     9672       1      1         3
# 1129          60         3         59.0    11796       1      1         0
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# 주피터 노트북 내 그래프 출력을 위한 설정
# %matplotlib inline

# 런타임오류들은 안뜨게 해줌
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# 1. 평가 함수
def evaluate_model(model, X_test, y_test):
    preds = model.predict(X_test)
    actual = np.expm1(y_test)
    predictions = np.expm1(preds)
    
    mae = mean_absolute_error(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    rmse = np.sqrt(mse)
    rmsle = np.sqrt(mean_squared_error(y_test, preds))
    r2 = r2_score(y_test, preds) # 로그 변환된 값 기준의 R2
    
    return [mae, mse, rmse, rmsle, r2]

# 2. 모델 리스트 확장
models = {
    "Linear": LinearRegression(),
    "Ridge": Ridge(alpha=10),
    "Lasso": Lasso(alpha=0.002),
    "RandomForest": RandomForestRegressor(n_estimators=100, random_state=42),
    "GradientBoosting": GradientBoostingRegressor(learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.8, random_state=42),
    "XGBoost": XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=3, subsample=0.5, random_state=42),
    "LightGBM": LGBMRegressor(n_estimators=500, learning_rate=0.05, colsample_bytree=0.5, num_leaves=5, random_state=42)
}

# 3. 학습 및 결과 도출
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    results[name] = evaluate_model(model, X_test, y_test)

# 4. 결과 비교 표
df_res = pd.DataFrame(results, index=['MAE', 'MSE', 'RMSE', 'RMSLE', 'R2']).T
print(df_res.sort_values(by='RMSLE')) # 성적 좋은 순(RMSLE 낮은 순)으로 정렬
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001306 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3115
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 72
# [LightGBM] [Info] Start training from score 12.028422
#                            MAE           MSE          RMSE     RMSLE        R2
# GradientBoosting  14286.673008  4.545316e+08  21319.745604  0.122081  0.905636
# LightGBM          13690.555940  3.733579e+08  19322.472145  0.126390  0.898856
# XGBoost           14014.743311  4.416859e+08  21016.324839  0.126421  0.898807
# Linear            14637.470178  4.351384e+08  20859.971815  0.127244  0.897486
# Ridge             14718.062169  4.410832e+08  21001.980250  0.128797  0.894968
# Lasso             14664.459133  4.544669e+08  21318.229295  0.133303  0.887490
# ...

# %% [markdown]
# #### 하이퍼파라미터 튜닝
# [GradientBoosting 튜닝 코드]

# %%
# 1. 시도해볼 후보 레시피(파라미터) 설정
param_grid = {
    'n_estimators': [100, 500],        # 나무를 몇 그루 심을지
    'learning_rate': [0.01, 0.05, 0.1], # 학습 속도 (너무 빠르면 놓치고, 느리면 오래 걸림)
    'max_depth': [3, 4, 5],             # 나무의 깊이 (너무 깊으면 과적합!)
    'subsample': [0.8, 1.0]             # 학습 시 데이터 사용 비율
}

# 2. 그리드 서치 설정 (모델, 후보군, 교차검증 5번)
grid_gb = GridSearchCV(GradientBoostingRegressor(random_state=42), 
                       param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# 3. 최적의 조합 찾기 (시간이 조금 걸릴 수 있어요!)
grid_gb.fit(X_train, y_train)

# 4. 결과 확인
print("최상의 레시피:", grid_gb.best_params_)

# 5. 최적의 모델로 다시 평가하기
best_gb = grid_gb.best_estimator_
final_res = evaluate_model(best_gb, X_test, y_test)
print(f"튜닝 후 RMSLE: {final_res[3]:.4f}, R2: {final_res[4]:.4f}")
# Out:
# 최상의 레시피: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'subsample': 0.8}
# 튜닝 후 RMSLE: 0.1221, R2: 0.9056

# %%
# 1. 시도해볼 후보 레시피(파라미터) 설정
param_grid = {
    'n_estimators': [700, 900],        # 나무를 몇 그루 심을지
    'learning_rate': [0.02, 0.03, 0.04], # 학습 속도 (너무 빠르면 놓치고, 느리면 오래 걸림)
    'max_depth': [2, 3, 4],             # 나무의 깊이 (너무 깊으면 과적합!)
    'subsample': [0.7, 0.9]             # 학습 시 데이터 사용 비율
}

# 2. 그리드 서치 설정 (모델, 후보군, 교차검증 5번)
grid_gb = GridSearchCV(GradientBoostingRegressor(random_state=42), 
                       param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# 3. 최적의 조합 찾기 (시간이 조금 걸릴 수 있어요!)
grid_gb.fit(X_train, y_train)

# 4. 결과 확인
print("최상의 레시피:", grid_gb.best_params_)

# 5. 최적의 모델로 다시 평가하기
best_gb = grid_gb.best_estimator_
final_res = evaluate_model(best_gb, X_test, y_test)
print(f"튜닝 후 RMSLE: {final_res[3]:.4f}, R2: {final_res[4]:.4f}")
# Out:
# 최상의 레시피: {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 900, 'subsample': 0.7}
# 튜닝 후 RMSLE: 0.1235, R2: 0.9035

# %% [markdown]
# ### 하이퍼파라미터 튜닝 방법
#
# 1. "경계값"을 확인하라 (Learning Curve & Validation)
# 범위를 [100, 500]으로 줬는데, 결과가 500에서 제일 좋게 나왔다면? 이건 **"더 큰 숫자가 필요하다"**는 신호입니다.
#
# 전략: 최적의 값이 내가 설정한 범위의 **끝단(Edge)**에 걸려 있다면, 범위를 그 방향으로 더 넓혀서 다시 돌려야 합니다.
#
# 반대로 최적값이 범위의 중간(300 같은 값)에 들어왔다면, 그 근처가 "진짜 맛있는 지점"일 확률이 높습니다.
#
# 2. "로그 스케일"로 크게 훑기 (Coarse-to-Fine)
# 처음부터 1, 2, 3, 4, 5... 이렇게 촘촘하게 찾으면 너무 오래 걸리고 비효율적입니다.
#
# 1단계 (성긴 탐색): 0.001, 0.1, 10, 100 처럼 10배씩 차이 나게 범위를 잡고 크게 훑습니다. (어느 동네가 땅값이 싼지 확인)
#
# 2단계 (정밀 탐색): 만약 10에서 결과가 제일 좋았다면, 그다음엔 5, 10, 15, 20 정도로 좁혀서 디테일하게 찾습니다. (그 동네 안에서 급매물 찾기)
#
# 3. "RandomizedSearchCV" (도박이 아닌 전략)
# GridSearchCV는 우리가 준 격자를 다 확인하지만, **RandomizedSearchCV**는 범위 내에서 무작위로 점을 찍어 테스트합니다.
#
# 이유: 어떤 파라미터는 성능에 큰 영향을 주지만, 어떤 건 거의 영향을 안 줍니다. 무작위로 찍다 보면 중요한 파라미터의 다양한 값을 더 빨리 테스트할 수 있어 훨씬 효율적입니다.
#
# 🛠️ 실전 팁: 모델별 "국룰" 바운더리
# 보통 입문 단계에서는 고수들이 미리 검증해놓은 범위를 먼저 써보는 게 정신 건강에 좋습니다.
#
# n_estimators (나무 개수): 보통 100으로 시작해서 성능이 안 나오면 500, 1000으로 늘립니다. (너무 많으면 느려짐)
#
# learning_rate (학습률): 0.01 ~ 0.1 사이가 가장 안정적입니다.
#
# max_depth (나무 깊이): 집값 데이터는 아주 복잡하지 않으므로 3 ~ 8 사이면 충분합니다. 그 이상은 과적합 위험이 커요.

# %% [markdown]
# ### 3대 모델 정밀 튜닝 (GridSearchCV)
# - 이 코드는 각 모델별로 가장 영향력이 큰 파라미터들만 골라서 최적의 조합을 찾아줍니다.

# %%
# 1. Lasso 튜닝: alpha(규제 강도)가 핵심입니다.
param_lasso = {'alpha': [0.0008, 0.001, 0.002, 0.003]}

# 2. XGBoost 튜닝: 트리 깊이와 학습률, 그리고 데이터 샘플링 비율이 중요합니다.
param_xgb = {
    'n_estimators': [500],
    'learning_rate': [0.03, 0.05],
    'max_depth': [3, 4],
    'subsample': [0.5, 0.7]
}

# 3. LightGBM 튜닝: XGB와 비슷하지만 속도가 빠르고 잎사귀(num_leaves) 중심입니다.
param_lgb = {
    'n_estimators': [500],
    'learning_rate': [0.03, 0.05],
    'num_leaves': [5, 20], # 기본값이 31입니다.
    'feature_fraction': [0.5, 0.7]
}

# 튜닝용 헬퍼 함수
def tune_model(model, params):
    grid = GridSearchCV(model, params, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    grid.fit(X_train, y_train)
    print(f"최적의 파라미터: {grid.best_params_}")
    return grid.best_estimator_

# 실행
print("--- Lasso 튜닝 시작 ---")
best_lasso = tune_model(Lasso(), param_lasso)

print("\n--- XGBoost 튜닝 시작 ---")
best_xgb = tune_model(XGBRegressor(random_state=42), param_xgb)

print("\n--- LightGBM 튜닝 시작 ---")
best_lgb = tune_model(LGBMRegressor(random_state=42), param_lgb)
# Out:
# --- Lasso 튜닝 시작 ---
# 최적의 파라미터: {'alpha': 0.002}
#
# --- XGBoost 튜닝 시작 ---
# 최적의 파라미터: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'subsample': 0.5}
#
# --- LightGBM 튜닝 시작 ---
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001236 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3115
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 72
# [LightGBM] [Info] Start training from score 12.028422
# 최적의 파라미터: {'feature_fraction': 0.5, 'learning_rate': 0.05, 'n_estimators': 500, 'num_leaves': 5}

# %%
# 각 모델의 예측값 뽑기
pred_gb = best_gb.predict(X_test)
pred_lasso = best_lasso.predict(X_test)
pred_xgb = best_xgb.predict(X_test)
pred_lgb = best_lgb.predict(X_test)

# 섞기 (가중치 평균) - 비중은 성능이 좋았던 순서대로 조절해보세요!
# 예: 성능 좋은 GBM과 Lasso에 비중을 더 많이 실어줍니다.
final_pred = (pred_gb * 0.4) + (pred_lasso * 0.3) + (pred_xgb * 0.15) + (pred_lgb * 0.15)

# 최종 성적 확인
from sklearn.metrics import mean_squared_error
final_rmsle = np.sqrt(mean_squared_error(y_test, final_pred))
print(f"앙상블 최종 RMSLE: {final_rmsle:.4f}")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# 앙상블 최종 RMSLE: 0.1224

# %%
# 1. 각 모델의 최적 설정값으로 모델 정의 (질문자님 성적 기반)
model_gb = GradientBoostingRegressor(learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.6, random_state=42)
model_xgb = XGBRegressor(learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.7, random_state=42)
model_lasso = Lasso(alpha=0.001) # 원래 잘 나왔던 설정값

# 2. 모델 학습
model_gb.fit(X_train, y_train)
model_xgb.fit(X_train, y_train)
model_lasso.fit(X_train, y_train)

# 3. 예측값 추출
pred_gb = model_gb.predict(X_test)
pred_xgb = model_xgb.predict(X_test)
pred_lasso = model_lasso.predict(X_test)

# 4. 가중치 섞기 (앙상블)
# 성적 1등(GB)에 50%, 2등(XGB)에 30%, 3등(Lasso)에 20% 비중
final_ensemble_pred = (pred_gb * 0.5) + (pred_xgb * 0.3) + (pred_lasso * 0.2)

# 5. 최종 성능 확인
from sklearn.metrics import mean_squared_error
final_rmsle = np.sqrt(mean_squared_error(y_test, final_ensemble_pred))
print(f"앙상블 최종 RMSLE: {final_rmsle:.4f}")
# Out:
# 앙상블 최종 RMSLE: 0.1211

# %% [markdown]
# #### 모델 자체를 파일로 저장하고 싶다면?

# %%
import joblib

# 모델 저장 (냉동 보관)
joblib.dump(model_gb, 'best_gb_model.pkl')
joblib.dump(model_xgb, 'best_xgb_model.pkl')

# 나중에 다시 쓸 때 (해동)
# loaded_model = joblib.load('best_gb_model.pkl')
# Out:
# ['best_xgb_model.pkl']

# %%
X_test_real.shape
# Out:
# (0, 79)

# %% [markdown]
# ### 실전: 결과물 뽑아내기 (Kaggle 제출용)

# %%
# 1. 진짜 시험지 로드 (Id 컬럼은 나중에 필요하므로 보관)
test = pd.read_csv('test.csv', index_col='Id')
test_id = test['Id']

# 2. [중요] Train 데이터와 똑같은 전처리를 Test 데이터에도 적용해야 합니다.
# (결측치 채우기, 인코딩 등 앞서 했던 과정을 거쳤다고 가정)
# X_test_real = 전처리가 끝난 test 데이터

# 3. 모델로 예측하기 (로그 변환 상태임)
final_test_pred = (model_gb.predict(X_test_real) * 0.5) + \
                  (model_xgb.predict(X_test_real) * 0.3) + \
                  (model_lasso.predict(X_test_real) * 0.2)

# 4. 로그를 다시 실제 가격으로 복구 (exp)
final_prices = np.expm1(final_test_pred)

# 5. 카글 양식에 맞춰 DataFrame 만들기
submission = pd.DataFrame({
    "Id": test_id,
    "SalePrice": final_prices
})

# 6. 드디어 파일로 저장! (내 컴퓨터에 submission.csv가 생깁니다)
submission.to_csv('my_submission.csv', index=False)
print("제출용 파일 생성 완료!")
# Out:
# 제출용 파일 생성 완료!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. 잔차(Error) 시ave 확인
models_to_compare = {
    "Lasso": Lasso(alpha=0.001),
    "GradientBoosting": GradientBoostingRegressor(learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.6, random_state=42)
}

plt.figure(figsize=(12, 5))

for i, (name, model) in enumerate(models_to_compare.items()):
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    residuals = y_test - preds
    
    plt.subplot(1, 2, i+1)
    sns.scatterplot(x=preds, y=residuals)
    plt.axhline(y=0, color='r', linestyle='--')
    plt.title(f"{name} Residual Plot")
    plt.xlabel("Predicted Values")
    plt.ylabel("Residuals")

plt.tight_layout()
plt.show()
