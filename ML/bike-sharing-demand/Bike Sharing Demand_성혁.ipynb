# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')

# %%
sampleSubmission = pd.read_csv('sampleSubmission.csv')

# %%
test = pd.read_csv('test.csv')

# %%
bike_df = pd.read_csv('./train.csv')
print(bike_df.shape)
bike_df.head(10)
# Out:
# (10886, 12)
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count
# 0        81     0.0000       3          13     16
# ...

# %%
bike_df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
bike_df = pd.read_csv('./test.csv')
print(bike_df.shape)
bike_df.head(10)
# Out:
# (6493, 9)
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 5  2011-01-20 05:00:00       1        0           1        1   9.84  11.365
# 6  2011-01-20 06:00:00       1        0           1        1   9.02  10.605
# 7  2011-01-20 07:00:00       1        0           1        1   9.02  10.605
# 8  2011-01-20 08:00:00       1        0           1        1   9.02  10.605
# 9  2011-01-20 09:00:00       1        0           1        2   9.84  11.365
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# ...

# %%
bike_df = pd.read_csv('./sampleSubmission.csv')
print(bike_df.shape)
bike_df.head(10)
# Out:
# (6493, 2)
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0
# 5  2011-01-20 05:00:00      0
# 6  2011-01-20 06:00:00      0
# 7  2011-01-20 07:00:00      0
# 8  2011-01-20 08:00:00      0
# 9  2011-01-20 09:00:00      0

# %%
bike_df.info(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  6493 non-null   object
#  1   count     6493 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 101.6+ KB

# %%
bike_df['datetime'] = bike_df.datetime.apply(pd.to_datetime)
bike_df['year'] = bike_df.datetime.apply(lambda x: x.year)
bike_df['month'] = bike_df.datetime.apply(lambda x: x.month)
bike_df['day'] = bike_df.datetime.apply(lambda x: x.day)
bike_df['hour'] = bike_df.datetime.apply(lambda x: x.hour)
bike_df.head(10)
# Out:
#              datetime  count  year  month  day  hour
# 0 2011-01-20 00:00:00      0  2011      1   20     0
# 1 2011-01-20 01:00:00      0  2011      1   20     1
# 2 2011-01-20 02:00:00      0  2011      1   20     2
# 3 2011-01-20 03:00:00      0  2011      1   20     3
# 4 2011-01-20 04:00:00      0  2011      1   20     4
# 5 2011-01-20 05:00:00      0  2011      1   20     5
# 6 2011-01-20 06:00:00      0  2011      1   20     6
# 7 2011-01-20 07:00:00      0  2011      1   20     7
# 8 2011-01-20 08:00:00      0  2011      1   20     8
# 9 2011-01-20 09:00:00      0  2011      1   20     9

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  6493 non-null   datetime64[ns]
#  1   count     6493 non-null   int64
#  2   year      6493 non-null   int64
#  3   month     6493 non-null   int64
#  4   day       6493 non-null   int64
#  5   hour      6493 non-null   int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 304.5 KB

# %%
bike_df.isnull().sum()
# Out:
# datetime    0
# count       0
# year        0
# month       0
# day         0
# hour        0
# dtype: int64

# %%
bike_df["datetime"] = pd.to_datetime(bike_df["datetime"])
bike_df["year"] = bike_df["datetime"].dt.year
bike_df["month"] = bike_df["datetime"].dt.month
bike_df["day"] = bike_df["datetime"].dt.day
bike_df["time"] = bike_df["datetime"].dt.time

# %%
bike_df.head()
# Out:
#              datetime  count  year  month  day  hour      time
# 0 2011-01-20 00:00:00      0  2011      1   20     0  00:00:00
# 1 2011-01-20 01:00:00      0  2011      1   20     1  01:00:00
# 2 2011-01-20 02:00:00      0  2011      1   20     2  02:00:00
# 3 2011-01-20 03:00:00      0  2011      1   20     3  03:00:00
# 4 2011-01-20 04:00:00      0  2011      1   20     4  04:00:00

# %%
bike_df.hist(figsize=(12, 10), bins=70)
plt.show()

# %%
sns.boxplot(data=train, x="workingday", y="count")
# Out:
# <Axes: xlabel='workingday', ylabel='count'>

# %%
sns.scatterplot(data=train, x="temp", y="count", hue="weather")
# Out:
# <Axes: xlabel='temp', ylabel='count'>

# %%
sns.barplot(data=train, x="weather", y="count")
# Out:
# <Axes: xlabel='weather', ylabel='count'>
