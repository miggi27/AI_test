# %% [markdown]
# #### 연령별 인구현황 피라미드
# - 연령별 인구현황 검색해서 자료 수집

# %% [markdown]
# ##### 판다스, 맵플롯립, 맵플롯립 한글 설정

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
## 맷플롯립 한글 설정
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# - 파일 이름 설정

# %%
filename = '201601_201601_연령별인구현황_월간.xlsx'

# %% [markdown]
# - 남자 데이터 파일 읽어오기(skiprows, usecols, index_col)

# %%
df_m = pd.read_excel(filename , skiprows=3 , usecols='b, e:y' , index_col='행정기관')
df_m.head()
# Out:
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,155,577  1,206,856  1,269,868  1,696,258  1,884,688  1,641,633
# 서울특별시      200,437    200,281    214,007    292,742    354,609    367,513
# 부산광역시       69,107     68,321     74,000    106,423    130,628    110,048
# 대구광역시       51,628     55,431     63,634     89,147     99,981     79,397
# 인천광역시       68,866     70,417     71,572     95,560    111,748     97,508
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,902,777  2,008,358  2,233,150  2,277,374  ...  2,031,839
# 서울특별시      427,894    407,957    429,079    420,928  ...    379,307
# 부산광역시      122,708    129,049    138,324    144,608  ...    154,315
# 대구광역시       82,404     89,552    104,114    112,145  ...     99,263
# 인천광역시      113,425    120,552    130,336    130,859  ...    119,223
#
#             60~64세     65~69세   70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       1,424,146  1,058,511  799,513  567,225  291,133  104,773  31,627
# 서울특별시      281,099    215,133  163,076  103,961   48,818   18,186   5,988
# 부산광역시      120,314     88,623   64,233   41,545   19,081    6,255   1,733
# 대구광역시       70,412     50,774   36,848   25,794   13,261    4,182   1,090
# 인천광역시       74,874     52,847   37,063   24,389   12,470    4,668   1,588
#
#         95~99세 100세 이상
# 행정기관
# 전국       7,069   3,832
# 서울특별시    1,781   1,314
# 부산광역시      370     322
# 대구광역시      219     120
# 인천광역시      386     194
#
# [5 rows x 21 columns]

# %%
df_m.iloc[0]
# Out:
# 0~4세       1,155,577
# 5~9세       1,206,856
# 10~14세     1,269,868
# 15~19세     1,696,258
# 20~24세     1,884,688
# 25~29세     1,641,633
# 30~34세     1,902,777
# 35~39세     2,008,358
# 40~44세     2,233,150
# 45~49세     2,277,374
# 50~54세     2,167,030
# 55~59세     2,031,839
# 60~64세     1,424,146
# 65~69세     1,058,511
# 70~74세       799,513
# 75~79세       567,225
# 80~84세       291,133
# 85~89세       104,773
# 90~94세        31,627
# 95~99세         7,069
# 100세 이상        3,832
# Name: 전국  , dtype: object

# %% [markdown]
# - 전국 인구 (콤마), 제외하고 숫자로 변환

# %%
df_m.head(3)
# Out:
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,155,577  1,206,856  1,269,868  1,696,258  1,884,688  1,641,633
# 서울특별시      200,437    200,281    214,007    292,742    354,609    367,513
# 부산광역시       69,107     68,321     74,000    106,423    130,628    110,048
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,902,777  2,008,358  2,233,150  2,277,374  ...  2,031,839
# 서울특별시      427,894    407,957    429,079    420,928  ...    379,307
# 부산광역시      122,708    129,049    138,324    144,608  ...    154,315
#
#             60~64세     65~69세   70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       1,424,146  1,058,511  799,513  567,225  291,133  104,773  31,627
# 서울특별시      281,099    215,133  163,076  103,961   48,818   18,186   5,988
# 부산광역시      120,314     88,623   64,233   41,545   19,081    6,255   1,733
#
#         95~99세 100세 이상
# 행정기관
# 전국       7,069   3,832
# 서울특별시    1,781   1,314
# 부산광역시      370     322
#
# [3 rows x 21 columns]

# %%
df_m.iloc[0]
# Out:
# 0~4세       1,155,577
# 5~9세       1,206,856
# 10~14세     1,269,868
# 15~19세     1,696,258
# 20~24세     1,884,688
# 25~29세     1,641,633
# 30~34세     1,902,777
# 35~39세     2,008,358
# 40~44세     2,233,150
# 45~49세     2,277,374
# 50~54세     2,167,030
# 55~59세     2,031,839
# 60~64세     1,424,146
# 65~69세     1,058,511
# 70~74세       799,513
# 75~79세       567,225
# 80~84세       291,133
# 85~89세       104,773
# 90~94세        31,627
# 95~99세         7,069
# 100세 이상        3,832
# Name: 전국  , dtype: object

# %%
df_m.iloc[0].str.replace(',','').astype(int)
# Out:
# 0~4세       1155577
# 5~9세       1206856
# 10~14세     1269868
# 15~19세     1696258
# 20~24세     1884688
# 25~29세     1641633
# 30~34세     1902777
# 35~39세     2008358
# 40~44세     2233150
# 45~49세     2277374
# 50~54세     2167030
# 55~59세     2031839
# 60~64세     1424146
# 65~69세     1058511
# 70~74세      799513
# 75~79세      567225
# 80~84세      291133
# 85~89세      104773
# 90~94세       31627
# 95~99세        7069
# 100세 이상       3832
# Name: 전국  , dtype: int64

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int)

# %%
df_m.iloc[0]
# Out:
# 0~4세       1155577
# 5~9세       1206856
# 10~14세     1269868
# 15~19세     1696258
# 20~24세     1884688
# 25~29세     1641633
# 30~34세     1902777
# 35~39세     2008358
# 40~44세     2233150
# 45~49세     2277374
# 50~54세     2167030
# 55~59세     2031839
# 60~64세     1424146
# 65~69세     1058511
# 70~74세      799513
# 75~79세      567225
# 80~84세      291133
# 85~89세      104773
# 90~94세       31627
# 95~99세        7069
# 100세 이상       3832
# Name: 전국  , dtype: object

# %%
df_m.head(3)
# Out:
#             0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국       1155577  1206856  1269868  1696258  1884688  1641633  1902777
# 서울특별시    200,437  200,281  214,007  292,742  354,609  367,513  427,894
# 부산광역시     69,107   68,321   74,000  106,423  130,628  110,048  122,708
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       2008358  2233150  2277374  ...  2031839  1424146  1058511   799513
# 서울특별시    407,957  429,079  420,928  ...  379,307  281,099  215,133  163,076
# 부산광역시    129,049  138,324  144,608  ...  154,315  120,314   88,623   64,233
#
#           75~79세  80~84세  85~89세 90~94세 95~99세 100세 이상
# 행정기관
# 전국        567225  291133  104773  31627   7069    3832
# 서울특별시    103,961  48,818  18,186  5,988  1,781   1,314
# 부산광역시     41,545  19,081   6,255  1,733    370     322
#
# [3 rows x 21 columns]

# %% [markdown]
# - 여자 데이터 파일 읽어오기

# %%
df_w = pd.read_excel(filename, skiprows=3, usecols='b, ab:av' , index_col='행정기관')
df_w.head(3)
# Out:
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       1,097,056  1,135,460  1,173,465  1,550,918  1,669,493  1,501,433
# 서울특별시      190,626    189,969    200,408    272,485    348,361    376,047
# 부산광역시       65,250     64,532     68,320     94,820    114,039    101,545
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,810,248  1,932,966  2,152,314  2,207,501  ...  2,031,127
# 서울특별시      424,773    404,376    427,085    425,947  ...    409,171
# 부산광역시      117,395    123,557    136,822    148,572  ...    165,289
#
#           60~64세.1   65~69세.1 70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       1,481,190  1,149,146  983,169  824,732  554,416  285,345  103,656
# 서울특별시      308,243    240,138  183,638  132,504   82,714   44,692   17,357
# 부산광역시      129,494     97,584   75,444   58,405   36,130   18,377    6,130
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        24,808    12,550
# 서울특별시      4,820     3,770
# 부산광역시      1,381     1,175
#
# [3 rows x 21 columns]

# %% [markdown]
# - 남자 데이터와 여자 데이터 컬럼명 일치시키기

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns

# %%
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.head(3)
# Out:
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,097,056  1,135,460  1,173,465  1,550,918  1,669,493  1,501,433
# 서울특별시      190,626    189,969    200,408    272,485    348,361    376,047
# 부산광역시       65,250     64,532     68,320     94,820    114,039    101,545
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,810,248  1,932,966  2,152,314  2,207,501  ...  2,031,127
# 서울특별시      424,773    404,376    427,085    425,947  ...    409,171
# 부산광역시      117,395    123,557    136,822    148,572  ...    165,289
#
#             60~64세     65~69세   70~74세   75~79세   80~84세   85~89세   90~94세  \
# 행정기관
# 전국       1,481,190  1,149,146  983,169  824,732  554,416  285,345  103,656
# 서울특별시      308,243    240,138  183,638  132,504   82,714   44,692   17,357
# 부산광역시      129,494     97,584   75,444   58,405   36,130   18,377    6,130
#
#          95~99세 100세 이상
# 행정기관
# 전국       24,808  12,550
# 서울특별시     4,820   3,770
# 부산광역시     1,381   1,175
#
# [3 rows x 21 columns]

# %% [markdown]
# - 전국 인구 (콤마), 제외하고 숫자로 변환

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int)

# %%
df_w.head(3)
# Out:
#             0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국       1097056  1135460  1173465  1550918  1669493  1501433  1810248
# 서울특별시    190,626  189,969  200,408  272,485  348,361  376,047  424,773
# 부산광역시     65,250   64,532   68,320   94,820  114,039  101,545  117,395
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       1932966  2152314  2207501  ...  2031127  1481190  1149146   983169
# 서울특별시    404,376  427,085  425,947  ...  409,171  308,243  240,138  183,638
# 부산광역시    123,557  136,822  148,572  ...  165,289  129,494   97,584   75,444
#
#           75~79세  80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국        824732  554416  285345  103656  24808   12550
# 서울특별시    132,504  82,714  44,692  17,357  4,820   3,770
# 부산광역시     58,405  36,130  18,377   6,130  1,381   1,175
#
# [3 rows x 21 columns]

# %%
df_w.iloc[0]
# Out:
# 0~4세       1097056
# 5~9세       1135460
# 10~14세     1173465
# 15~19세     1550918
# 20~24세     1669493
# 25~29세     1501433
# 30~34세     1810248
# 35~39세     1932966
# 40~44세     2152314
# 45~49세     2207501
# 50~54세     2097352
# 55~59세     2031127
# 60~64세     1481190
# 65~69세     1149146
# 70~74세      983169
# 75~79세      824732
# 80~84세      554416
# 85~89세      285345
# 90~94세      103656
# 95~99세       24808
# 100세 이상      12550
# Name: 전국  , dtype: object

# %% [markdown]
# - 인구 피라미드 시각화, 크기( 15, 9 ), barh, 제목(2016년 인구 피라미드), png 파일 저장

# %%
plt.figure(figsize=(15,9))
plt.barh(df_m.columns , -df_m.iloc[0] // 1000)
plt.barh(df_w.columns , df_w.iloc[0] // 1000)
plt.title('2016년 인구 피라미드')
plt.savefig('2016년 인구 피라미드.png' , dpi=100)
plt.show()

# %% [markdown]
# - 2026년 인구 통계 분석

# %% [markdown]
# - 파일 이름 설정

# %%
filename = '202601_202601_연령별인구현황_월간.xlsx'

# %% [markdown]
# - 위에서 작업한 내용 종합해서 2026년 인구 피라미드 작성

# %%
df_m = pd.read_excel(filename, skiprows=3, usecols='b, e:y', index_col='행정기관')
# df_m.head()
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int)
df_w = pd.read_excel(filename, skiprows=3, usecols='b, ab:av', index_col='행정기관')
# df_m.head()
df_w.columns = df_m.columns
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int)

plt.figure(figsize=(15,9))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000)
plt.barh(df_w.columns, df_w.iloc[0] // 1000)
plt.title('2026년 인구 현황')
plt.savefig('2026년 인구 현황.png', dpi=100)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
